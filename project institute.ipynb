# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # New Section

# %%
from google.colab import files
up=files.upload()
# Out:
#      <input type="file" id="files-61f7a744-33b2-4d59-b617-0a6b2a181d7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61f7a744-33b2-4d59-b617-0a6b2a181d7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('institute project.xlsx')
df
# Out:
#         NAME OF THE  STUDENT QUALIFICATION  \
# 0                     Rakesh         BTECH
# 1    Lingamgari Charan Teja          BTECH
# 2               Sharuk Shaik         BTECH
# 3           C Krithik Reddy          BTECH
# 4         Shubham Kumar Roy          BTECH
# ..                       ...           ...
# 225                    Riya         OTHERS
# 226        Kottapally Sreya          BTECH
# 227       Vanaparthi Anjali          BTECH
# 228                T.Tejaswi         BTECH
# 229              Vijaya Sri          BTECH
#
#                                      NAME OF COLLEGE  YEAR OF GRADUATION  \
# 0    Kg Reddy college of engineering and technology                 2026
# 1                  Aar Mahaveer Engineering College                 2026
# 2                               Kakatiya University                 2026
# 3      Mahaveer Institute of Science and Technology                 2026
# 4      Mahaveer institute of science and technology                 2026
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 15 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   NAME OF THE  STUDENT                                            230 non-null    object
#  1   QUALIFICATION                                                   230 non-null    object
#  2   NAME OF COLLEGE                                                 230 non-null    object
#  3   YEAR OF GRADUATION                                              230 non-null    int64
#  4   STREAM OF GRADUATION                                            230 non-null    object
#  5   COURSE
#                                                         230 non-null    object
#  6   EXPECTED DURATION OF COURSE                                     230 non-null    object
#  7   MONTH OF JOINING
#
# ...

# %%
df.describe()
# Out:
#        YEAR OF GRADUATION           MONTH OF JOINING\n\n  \
# count          230.000000                            230
# mean          2025.860870  2025-12-14 12:12:31.304347904
# min           2022.000000            2025-11-01 00:00:00
# 25%           2026.000000            2025-12-01 00:00:00
# 50%           2026.000000            2025-12-01 00:00:00
# 75%           2026.000000            2026-01-01 00:00:00
# max           2026.000000            2026-02-01 00:00:00
# std              0.474447                            NaN
#
#        SATISFACTION LEVEL OF FEE STRUCTURE  \
# count                           230.000000
# mean                              4.078261
# min                               1.000000
# 25%                               3.000000
# 50%                               5.000000
# 75%                               5.000000
# max                               5.000000
# std                               1.208759
#
# ...

# %%
df.duplicated().count()
# Out:
# np.int64(230)

# %%
df['WHAT SHOULD BE IMPROVED IN INSTITUTE FOR STUDENTS SATISFACTION'] = \
df['WHAT SHOULD BE IMPROVED IN INSTITUTE FOR STUDENTS SATISFACTION'].fillna('Nothing')
df
# Out:
#         NAME OF THE  STUDENT QUALIFICATION  \
# 0                     Rakesh         BTECH
# 1    Lingamgari Charan Teja          BTECH
# 2               Sharuk Shaik         BTECH
# 3           C Krithik Reddy          BTECH
# 4         Shubham Kumar Roy          BTECH
# ..                       ...           ...
# 225                    Riya         OTHERS
# 226        Kottapally Sreya          BTECH
# 227       Vanaparthi Anjali          BTECH
# 228                T.Tejaswi         BTECH
# 229              Vijaya Sri          BTECH
#
#                                      NAME OF COLLEGE  YEAR OF GRADUATION  \
# 0    Kg Reddy college of engineering and technology                 2026
# 1                  Aar Mahaveer Engineering College                 2026
# 2                               Kakatiya University                 2026
# 3      Mahaveer Institute of Science and Technology                 2026
# 4      Mahaveer institute of science and technology                 2026
# ...

# %%
df['NAME OF COLLEGE'] = (df['NAME OF COLLEGE'].str.lower())
df['COURSE \n'] = (df['COURSE \n'].str.lower())
df['WHAT SHOULD BE IMPROVED IN INSTITUTE FOR STUDENTS SATISFACTION']=(df['WHAT SHOULD BE IMPROVED IN INSTITUTE FOR STUDENTS SATISFACTION'].str.lower())
df.head()
# Out:
#       NAME OF THE  STUDENT QUALIFICATION  \
# 0                   Rakesh         BTECH
# 1  Lingamgari Charan Teja          BTECH
# 2             Sharuk Shaik         BTECH
# 3         C Krithik Reddy          BTECH
# 4       Shubham Kumar Roy          BTECH
#
#                                    NAME OF COLLEGE  YEAR OF GRADUATION  \
# 0  kg reddy college of engineering and technology                 2026
# 1                aar mahaveer engineering college                 2026
# 2                             kakatiya university                 2026
# 3    mahaveer institute of science and technology                 2026
# 4    mahaveer institute of science and technology                 2026
#
#   STREAM OF GRADUATION          COURSE \n EXPECTED DURATION OF COURSE  \
# 0                  CSE  python full stack                    6 Months
# 1                  CSE  python full stack                    4 Months
# 2                  CSE      data science                     3 Months
# ...

# %%
df['CHANCES OF GETTING PLACEMENTS'].mode()
# Out:
# 0    4.0
# Name: CHANCES OF GETTING PLACEMENTS, dtype: float64

# %%
df['CHANCES OF GETTING PLACEMENTS'].fillna(4.0,inplace=True)
df
# Out:
# /tmp/ipython-input-2499102606.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CHANCES OF GETTING PLACEMENTS'].fillna(4.0,inplace=True)
#         NAME OF THE  STUDENT QUALIFICATION  \
# 0                     Rakesh         BTECH
# 1    Lingamgari Charan Teja          BTECH
# 2               Sharuk Shaik         BTECH
# 3           C Krithik Reddy          BTECH
# 4         Shubham Kumar Roy          BTECH
# ..                       ...           ...
# 225                    Riya         OTHERS
# ...

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 227 entries, 0 to 229
# Data columns (total 15 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   NAME OF THE  STUDENT                                            227 non-null    object
#  1   QUALIFICATION                                                   227 non-null    object
#  2   NAME OF COLLEGE                                                 227 non-null    object
#  3   YEAR OF GRADUATION                                              227 non-null    int64
#  4   STREAM OF GRADUATION                                            227 non-null    object
#  5   COURSE
#                                                         227 non-null    object
#  6   EXPECTED DURATION OF COURSE                                     227 non-null    object
#  7   MONTH OF JOINING
#
# ...

# %%
df['STATISFACTION LEVEL OF TRAINERS QUALITY'].mean()
# Out:
# np.float64(4.392070484581498)

# %%
df['SATISFACTION LEVEL OF FEE STRUCTURE'].mean()
# Out:
# np.float64(4.070484581497797)

# %%
df['CHANCES OF GETTING PLACEMENTS'].mean()
# Out:
# np.float64(3.647577092511013)

# %%
df.groupby('COURSE \n').size()
# Out:
# COURSE \n
# data analytics                            38
# data science                              20
# java full stack                           52
# python full atack                          1
# python full stack                         78
# python full stack                          3
# python full stack with data analyst        1
# python full stack with data analytics      1
# python full stock                          1
# python with data science                   1
# software testing                          31
# dtype: int64

# %%
df['COURSE \n'] = ( df['COURSE \n'] .str.strip() .str.lower()
    .str.replace('python full atack', ' python full stack')
    .str.replace('python full stock', 'python full stack')
    .str.replace('python full stack with data analyst', 'python full stack with data analytics')
     .str.replace('python full stack', 'python full stack')
)
df.groupby('COURSE \n').size()
# Out:
# COURSE \n
#  python full stack                        1
# data analytics                           38
# data science                             20
# java full stack                          52
# python full stack                        82
# python full stack with data analytics     2
# python with data science                  1
# software testing                         31
# dtype: int64

# %%
df['EXPECTED DURATION OF COURSE'].mode()
# Out:
# 0    3 Months
# Name: EXPECTED DURATION OF COURSE, dtype: object

# %%
df.groupby('HOW DID YOU KNOW ABOUT THIS INSTITUTE').size()
# Out:
# HOW DID YOU KNOW ABOUT THIS INSTITUTE
# ADVERTISEMENT                  8
# College placement            116
# College placement              1
# FRIEND REFERENCE              76
# From College Authorities       1
# GOOGLE SEARCHED                7
# In our placement               1
# Incubation                     1
# SOCIAL MEDIA                  16
# dtype: int64

# %%
df.groupby('YEAR OF GRADUATION').size()
# Out:
# YEAR OF GRADUATION
# 2022      2
# 2025     23
# 2026    202
# dtype: int64

# %%
#df.to_excel('instituteproject_out.xlsx',index=False)
#from google.colab import files
#files.download("instituteproject_out.xlsx")
